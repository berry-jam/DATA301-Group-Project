# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('crimes_per_region.csv')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4362 entries, 0 to 4361
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Location    4362 non-null   object
#  1   Age         4362 non-null   object
#  2   Gender      4362 non-null   object
#  3   Ethnicity   4362 non-null   object
#  4   Resolution  4362 non-null   object
#  5   Offence     4362 non-null   object
#  6   Year        4362 non-null   int64
#  7   Value       4362 non-null   int64
#  8   Flags       0 non-null      float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 306.8+ KB
#             Location        Age        Gender        Ethnicity  \
# 0  Auckland District  Total Age  Total Gender  Total Ethnicity
# 1  Auckland District  Total Age  Total Gender  Total Ethnicity
# 2  Auckland District  Total Age  Total Gender  Total Ethnicity
# 3  Auckland District  Total Age  Total Gender  Total Ethnicity
# ...

# %%
#extact the needed columns 
data = df[["Location", "Offence", "Year", "Value"]]

# %%
#sort by Location
data2 = data.sort_values('Location')

# %%
data2
# Out:
#                  Location                                            Offence  \
# 0       Auckland District              Fraud, deception and related offences
# 1262    Auckland District              Fraud, deception and related offences
# 1263    Auckland District              Fraud, deception and related offences
# 1264    Auckland District              Fraud, deception and related offences
# 1265    Auckland District              Fraud, deception and related offences
# ...                   ...                                                ...
# 1958  Wellington District  Prohibited and regulated weapons and explosive...
# 1959  Wellington District  Prohibited and regulated weapons and explosive...
# 1960  Wellington District  Prohibited and regulated weapons and explosive...
# 1952  Wellington District                              Illicit drug offences
# 3682  Wellington District                             Miscellaneous offences
#
#       Year  Value
# 0     1994   2027
# ...

# %%
data4['Territorial Authority'] = data4['Territorial Authority'].astype('category')
data4['Anzsoc Division'] = data4['Anzsoc Division'].astype('category')
data4['Year Month'] = data4['Year Month'].astype('category')
data4['Victimisations'] = data4['Victimisations'].astype('category')

# %%
df1 = pd.read_csv("victimization_nationwide.csv")
df1.info()
df1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 737388 entries, 0 to 737387
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Anzsoc Division        737388 non-null  object
#  1   Year Month             737388 non-null  object
#  2   Territorial Authority  737388 non-null  object
#  3   Victimisations         737388 non-null  int64
#  4   Unnamed: 4             0 non-null       float64
#  5   Unnamed: 5             0 non-null       float64
#  6   Unnamed: 6             0 non-null       float64
#  7   Unnamed: 7             0 non-null       float64
#  8   Unnamed: 8             0 non-null       float64
#  9   Unnamed: 9             0 non-null       float64
#  10  Unnamed: 10            0 non-null       float64
#  11  Unnamed: 11            0 non-null       float64
#  12  Unnamed: 12            0 non-null       float64
#  13  Unnamed: 13            0 non-null       float64
# ...

# %%
#extract the needed column
data3 = df1[["Territorial Authority", "Anzsoc Division", "Year Month","Victimisations"]]
data3.head()
# Out:
#   Territorial Authority                Anzsoc Division Year Month  \
# 0    Christchurch City.  Acts Intended to Cause Injury  2014/1/12
# 1    Christchurch City.  Acts Intended to Cause Injury  2014/1/12
# 2   Ashburton District.  Acts Intended to Cause Injury  2014/1/12
# 3      Timaru District.  Acts Intended to Cause Injury  2014/1/12
# 4      Timaru District.  Acts Intended to Cause Injury  2014/1/12
#
#    Victimisations
# 0               2
# 1               7
# 2               2
# 3               1
# 4               3

# %%
#sort by Territory
data4 = data3.sort_values('Territorial Authority')
data4
# Out:
#                       Territorial Authority                Anzsoc Division  \
# 126376  Area Outside Territorial Authority.     Theft and Related Offences
# 430907  Area Outside Territorial Authority.     Theft and Related Offences
# 125687  Area Outside Territorial Authority.     Theft and Related Offences
# 33044   Area Outside Territorial Authority.  Acts Intended to Cause Injury
# 167010  Area Outside Territorial Authority.     Theft and Related Offences
# ...                                     ...                            ...
# 181594                  Whangarei District.  Acts Intended to Cause Injury
# 75726                   Whangarei District.     Theft and Related Offences
# 75729                   Whangarei District.     Theft and Related Offences
# 75683                   Whangarei District.     Theft and Related Offences
# 281860                  Whangarei District.     Theft and Related Offences
#
#        Year Month  Victimisations
# ...
