# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('Covid_calls for service.csv')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43782 entries, 0 to 43781
# Data columns (total 7 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   District                          43782 non-null  object
#  1   Alert Level                       43782 non-null  int64
#  2   Calls for Service and Prevention  43782 non-null  object
#  3   Crime and NonCrime Demand         43782 non-null  object
#  4   Event Category                    43782 non-null  object
#  5   Event Type                        43782 non-null  object
#  6   No                                43782 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 2.3+ MB
#         District  Alert Level Calls for Service and Prevention  \
# 0  Auckland City            2                           Demand
# 1  Auckland City            2                           Demand
# ...

# %%
df1 = pd.read_csv('victimisation_time and place_original.csv', encoding='latin-1')
df1.info()
df1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699705 entries, 0 to 699704
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   ANZSOC Division         699705 non-null  object
#  1   Year Month              699705 non-null  object
#  2    Month Year             699705 non-null  object
#  3   ANZSOC Group            699705 non-null  object
#  4   ANZSOC Subdivision      699705 non-null  object
#  5   Area Unit               699705 non-null  object
#  6   Location Type           699705 non-null  object
#  7   Locn Type Division      699705 non-null  object
#  8   Meshblock               699705 non-null  int64
#  9   Occurrence Day Of Week  699705 non-null  object
#  10  Occurrence Hour Of Day  699703 non-null  float64
#  11  Table 1                 699705 non-null  object
#  12  Territorial Authority   699705 non-null  object
#  13  Weapon                  699705 non-null  object
# ...
